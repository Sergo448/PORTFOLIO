# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import zipfile

# %%
# %time
print('Extracting ZIP.')
z = zipfile.ZipFile('P:\\Python Projects\\AI_curces\\O_Reily\\datasets\\all_mtg_cards.csv.zip', 'r')
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Extracting ZIP.

# %%
z.extractall(path='P:\\Python Projects\\AI_curces\\O_Reily\\datasets\\data')

# %%
df = pd.read_csv('.//datasets//data//all_mtg_cards.csv')
# Out:
# C:\Users\Сергей\AppData\Local\Temp\ipykernel_20924\3173835817.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('.//datasets//data//all_mtg_cards.csv')

# %%
df.head(5)
# Out:
#                 name  multiverse_id  layout  names  mana_cost  cmc     colors  \
# 0  Ancestor's Chosen       130550.0  normal    NaN  {5}{W}{W}  7.0  ['White']
# 1  Ancestor's Chosen            NaN  normal    NaN  {5}{W}{W}  7.0  ['White']
# 2     Angel of Mercy       129465.0  normal    NaN     {4}{W}  5.0  ['White']
# 3     Angel of Mercy            NaN  normal    NaN     {4}{W}  5.0  ['White']
# 4   Angelic Blessing       129711.0  normal    NaN     {2}{W}  3.0  ['White']
#
#   color_identity                     type supertypes  ...  \
# 0          ['W']  Creature — Human Cleric        NaN  ...
# 1          ['W']  Creature — Human Cleric        NaN  ...
# 2          ['W']         Creature — Angel        NaN  ...
# 3          ['W']         Creature — Angel        NaN  ...
# 4          ['W']                  Sorcery        NaN  ...
#
#                                        foreign_names  \
# 0  [{'name': 'Ausgewählter der Ahnfrau', 'text': ...
# ...

# %%
df.tail(5)
# Out:
#                       name  multiverse_id  layout  names  mana_cost  cmc  \
# 66765        Into the Roil            NaN  normal    NaN     {1}{U}  2.0
# 66766  Bloodchief's Thirst            NaN  normal    NaN        {B}  1.0
# 66767        Roil Eruption            NaN  normal    NaN     {1}{R}  2.0
# 66768     Roiling Regrowth            NaN  normal    NaN     {2}{G}  3.0
# 66769     Kargan Warleader            NaN  normal    NaN  {1}{R}{W}  3.0
#
#                  colors color_identity                      type supertypes  \
# 66765          ['Blue']          ['U']                   Instant        NaN
# 66766         ['Black']          ['B']                   Sorcery        NaN
# 66767           ['Red']          ['R']                   Sorcery        NaN
# 66768         ['Green']          ['G']                   Instant        NaN
# 66769  ['Red', 'White']     ['R', 'W']  Creature — Human Warrior        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66770 entries, 0 to 66769
# Data columns (total 39 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            66770 non-null  object
#  1   multiverse_id   47455 non-null  float64
#  2   layout          66770 non-null  object
#  3   names           0 non-null      float64
#  4   mana_cost       58100 non-null  object
#  5   cmc             66770 non-null  float64
#  6   colors          52612 non-null  object
#  7   color_identity  59739 non-null  object
#  8   type            66770 non-null  object
#  9   supertypes      9912 non-null   object
#  10  subtypes        40903 non-null  object
#  11  rarity          66770 non-null  object
#  12  text            65805 non-null  object
#  13  flavor          34412 non-null  object
#  14  artist          66759 non-null  object
#  15  number          66770 non-null  object
#  16  power           31332 non-null  object
# ...

# %%
data = df.copy(d)

# %%
data = data.drop_duplicates()

# %%
data_task_1 = data[['colors', 'rarity']].dropna()

# %%
data_task_1
# Out:
#                  colors    rarity
# 0             ['White']  Uncommon
# 1             ['White']  Uncommon
# 2             ['White']  Uncommon
# 3             ['White']  Uncommon
# 4             ['White']    Common
# ...                 ...       ...
# 66765          ['Blue']    Common
# 66766         ['Black']  Uncommon
# 66767           ['Red']    Common
# 66768         ['Green']  Uncommon
# 66769  ['Red', 'White']  Uncommon
#
# [52612 rows x 2 columns]

# %%
data_task_1['colors'].unique()
# Out:
# array(["['White']", "['Blue']", "['Black']", "['Red']", "['Green']",
#        "['Green', 'Blue']", "['Black', 'Green', 'Blue', 'White']",
#        "['Black', 'Blue']", "['Black', 'Red', 'Blue', 'White']",
#        "['Red', 'Blue']", "['Black', 'Green']", "['Black', 'Red']",
#        "['Blue', 'White']", "['Green', 'Red']", "['Black', 'White']",
#        "['Black', 'Red', 'White']", "['Black', 'Green', 'Red']",
#        "['Black', 'Green', 'Red', 'Blue', 'White']", "['Green', 'White']",
#        "['Green', 'Red', 'Blue']", "['Black', 'Blue', 'White']",
#        "['Red', 'White']", "['Black', 'Red', 'Blue']",
#        "['Green', 'Blue', 'White']", "['Green', 'Red', 'White']",
#        "['Black', 'Green', 'Blue']", "['Red', 'Blue', 'White']",
#        "['Black', 'Green', 'White']", "['Green', 'Red', 'Blue', 'White']",
#        "['Black', 'Green', 'Red', 'White']",
#        "['Black', 'Green', 'Red', 'Blue']", "['White', 'Blue']",
# ...

# %%
data_task_1["num_colors"] = data_task_1[i for i in data_task_1["colors"].unique()]
# Out:
#   Input In [62]
#     data_task_1["num_colors"] = data_task_1[i for i in data_task_1["colors"].unique()]
#                                               ^
# SyntaxError: invalid syntax

# %%
colors_unique = data_task_1['colors'].unique()
colors_unique_i = []

# %%
for colors in colors_unique:
    colors_unique_i.append(colors_unique.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [68], in <module>
#       1 for colors in colors_unique:
# ----> 2     colors_unique_i.append(colors_unique.index)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %% [markdown]
# Для цветов будем использовать колонку colors
#
# Для редкости будем использовать колонку rarity

# %% [markdown]
# # task_1

# %%
sns.barplot(x=np.arange("colors"), y=np.arange("rarity"), data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 sns.barplot(x=np.arange("colors"), y=np.arange("rarity"), data=df)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
